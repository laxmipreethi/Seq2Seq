# %% [markdown]
# <a href="https://colab.research.google.com/github/laxmipreethi/Seq2Seq/blob/master/Joint_SLT_Transformer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/neccam/slt.git
# Out:
# Cloning into 'slt'...
# remote: Enumerating objects: 93, done.
# remote: Counting objects: 100% (93/93), done.
# remote: Compressing objects: 100% (79/79), done.
# remote: Total 93 (delta 15), reused 57 (delta 0), pack-reused 0
# Unpacking objects: 100% (93/93), done.

# %%
# !bash /content/slt/data/download.sh
# Out:
# --2020-09-04 10:10:59--  http://cihancamgoz.com/files/cvpr2020/phoenix14t.pami0.train
# Resolving cihancamgoz.com (cihancamgoz.com)... 192.232.218.145
# Connecting to cihancamgoz.com (cihancamgoz.com)|192.232.218.145|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1935289362 (1.8G)
# Saving to: ‘phoenix14t.pami0.train’
#
# phoenix14t.pami0.tr 100%[===================>]   1.80G  17.4MB/s    in 1m 49s
#
# 2020-09-04 10:12:49 (16.9 MB/s) - ‘phoenix14t.pami0.train’ saved [1935289362/1935289362]
#
# --2020-09-04 10:12:49--  http://cihancamgoz.com/files/cvpr2020/phoenix14t.pami0.dev
# Resolving cihancamgoz.com (cihancamgoz.com)... 192.232.218.145
# Connecting to cihancamgoz.com (cihancamgoz.com)|192.232.218.145|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 130831227 (125M)
# Saving to: ‘phoenix14t.pami0.dev’
#
# phoenix14t.pami0.de 100%[===================>] 124.77M  20.4MB/s    in 7.1s
#
# ...

# %%
# !cat /content/phoenix14t.pami0.dev | head -5
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-4-14014506157c> in <module>()
# ----> 1 get_ipython().system('cat /content/phoenix14t.pami0.dev | head -5')
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_shell.py in system(self, *args, **kwargs)
#     100       kwargs.update({'also_return_output': True})
#     101
# --> 102     output = _system_commands._system_compat(self, *args, **kwargs)  # pylint:disable=protected-access
#     103
#     104     if pip_warn:
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_system_commands.py in _system_compat(shell, cmd, also_return_output)
#     438   # stack.
#     439   result = _run_command(
# --> 440       shell.var_expand(cmd, depth=2), clear_streamed_output=False)
#     441   shell.user_ns['_exit_code'] = result.returncode
#     442   if -result.returncode in _INTERRUPTED_SIGNALS:
#
# ...

# %%
# !chmod +x /content/slt/data/download.sh

# %%
# !cd slt && pip install -r requirements.txt

# %%
# !cd slt && python -m signjoey train /content/slt/configs/sign.yaml
# Out:
# 2020-08-31 03:16:45.279104: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libnvinfer.so.6'; dlerror: libnvinfer.so.6: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2020-08-31 03:16:45.279296: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libnvinfer_plugin.so.6'; dlerror: libnvinfer_plugin.so.6: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2020-08-31 03:16:45.279317: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:30] Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2020-08-31 03:17:38,599 Hello! This is Joey-NMT.
# 2020-08-31 03:17:38,603 Total params: 26114111
# ...

# %%
# !/usr/bin/env bash
# Out:
# bash: cannot set terminal process group (103): Inappropriate ioctl for device
# bash: no job control in this shell
# root@2eb57fb74202:/content#
